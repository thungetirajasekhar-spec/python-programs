# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]
plt.plot(x, y, marker='o') 
plt.title('Line Chart Example')
plt.xlabel('X-axis') 
plt.ylabel('Y-axis') 
plt.grid(True)  
plt.show()

# %%
import matplotlib.pyplot as plt
categories = ['A', 'B', 'C', 'D', 'E']
values = [5, 7, 3, 8, 6]
plt.bar(categories, values) 
plt.xlabel('Categories')  
plt.ylabel('Values') 
plt.title('Bar Chart Example')  
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
y = [1,2,5,8,9]
plt.plot(x, y, marker='*') 
plt.title('Line Chart')
plt.xlabel('X-axis') 
plt.ylabel('Y-axis') 
plt.grid(True)  
plt.show()

# %%
import matplotlib.pyplot as plt
languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C/C++']
 percentages = [20.2, 17.6, 8.8, 8, 7.7]
colors = ['red', 'yellow', 'pink', 'brown','black']
plt.pie(percentages, labels=languages, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Popular Programming Languages')
plt.show()

# %%
import matplotlib.pyplot as plt
price=[2.50,4.02,3.25,5.00,4.40,1.23]
sales_per_day=[34,62,49,22,13,19]
plt.scatter(price,sales_per_day)
plt.show()

# %%
import pandas as pd
file_path = ('C:\Users\T Rajashekar\Desktop\python\Iris.csv')
df = pd.read_csv(file_path)
print(df.head())
# Out:
#   Cell In[100], line 2
#     file_path = ('C:\Users\T Rajashekar\Desktop\python\Iris.csv')
#                  ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [5, 7, 8, 5, 6]
sizes = [20, 50, 80, 60, 40]  
plt.scatter(x, y, s=sizes, alpha=0.5)  
plt.xlabel('X-axis') 
plt.ylabel('Y-axis')  
plt.title('Bubble Plot Example') 
plt.show()

# %%
import seaborn as sns
df=sns.load_dataset('iris')
sns.regplotx=df("sepal_length"),y_df("sepal_width")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 import seaborn as sns
#       2 df=sns.load_dataset('iris')
# ----> 3 sns.regplotx=df("sepal_length"),
#       4 y_df("sepal_width")
#
# TypeError: 'DataFrame' object is not callable

# %%
print(vani)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(vani)
#
# NameError: name 'vani' is not defined

# %%
print(chaithu)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(chaithu)
#
# NameError: name 'chaithu' is not defined

# %%
print(raju)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(raju)
#
# NameError: name 'raju' is not defined

# %%
import numpy as np
print(raj)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 import numpy as np
# ----> 2 print(raj)
#
# NameError: name 'raj' is not defined
