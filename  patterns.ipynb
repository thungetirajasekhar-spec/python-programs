# %%
a=[1,2,3,4]
for i in a:
    print('*'* i)
    print()
# Out:
# *
# **
# ***
# ****

# %%
 arr = ["****","    ","    ","****"]

for i in arr:
    print("*", i, "*")
# Out:
# * **** *
# *      *
# *      *
# * **** *

# %%
r=4
c=19
for i in range(r):
    for j in range(c):
        if i==0 or i==r-1 or j==0 or j==c-1:
            print("*",end="")
        else:
            print(" ",end="")
        #if j!=c-1:
         #  print(" ",end="")
    print()
# Out:
# *******************
# *                 *
# *                 *
# *******************

# %%
r=4
c=10
for i in range(r):
    for j in range(c):
       
        if j!=c-1:
            print("*",end=" ")
    print()
# Out:
# * * * * * * * * *
# * * * * * * * * *
# * * * * * * * * *
# * * * * * * * * *

# %%
 r=4
c=8
for i in range(r):
    for j in range(c):
        if i==0 or j==0 or j==1:
            print("*",end="")
       
        #if j!=c-1:
         #   print("*",end=" ")
    print()
# Out:
# ********
# **
# **
# **
