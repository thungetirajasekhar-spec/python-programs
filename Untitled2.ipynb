# %%
import matplotlib.pyplot as plt
import numpy as np
labals=['A','B','C','D']
values=[4,7,1,5]
values+=values[:1]
angles=np.linspace(0,2*np.pi,len(labals),endpoint=False).tolist()
angles+=angles[:1]
fig,ax=plt.subplots(figsize=(6,6),subplot_kw=dict(polar=True))
ax.fill(angles,values,color='black',alpha=0.25)
ax.plot(angles,values, color='black',linewidth=2)
ax.set_yticklabels([])
ax.set_xticks(angles[:-1])
ax.set_xticklabels(labals)
plt.show()

# %%
import matplotlib.pyplot as plt
hours=[17,20,25,26,27,30,31,32,38,40,40,45,55]
fig,ax=plt.subplots(figsize=(3,9))
ax.hist(hours,bins=5,edgecolor='black');

# %%
import matplotlib.pyplot as plt
import numpy as np
x=range(1,41)
values=np.random.uniform(size=40)
plt.stem(x, values)
plt.ylim(0, 1.2)
plt.show()
