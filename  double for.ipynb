# %%
li=[5,8,10,11,15,50,15,25,55,20]
print(min(li))
# Out:
# 5

# %%
list=[6,3,8,9,10]
 pei
print(max(1,2,3,4,5))
# Out:
# 5

# %%
n=2
m=3
for i in range(2,10,2):
    print(n,"*",i,"=",n*i)
    for j in range(2,10,2):
        print(m,"*",j,"=",m*j )
# Out:
# 2 * 2 = 4
# 3 * 2 = 6
# 3 * 4 = 12
# 3 * 6 = 18
# 3 * 8 = 24
# 2 * 4 = 8
# 3 * 2 = 6
# 3 * 4 = 12
# 3 * 6 = 18
# 3 * 8 = 24
# 2 * 6 = 12
# 3 * 2 = 6
# 3 * 4 = 12
# 3 * 6 = 18
# 3 * 8 = 24
# 2 * 8 = 16
# 3 * 2 = 6
# 3 * 4 = 12
# 3 * 6 = 18
# 3 * 8 = 24

# %%
n=4
for i in range(2,12,2):
    print(n,"*",i,"=",n*i)
# Out:
# 4 * 2 = 8
# 4 * 4 = 16
# 4 * 6 = 24
# 4 * 8 = 32
# 4 * 10 = 40

# %%
sentences = ["This is a sentence", "Short one", "This is the longest sentence here"]
ans = 0
for i in sentences:
    temp = 1
    for j in i:
        if j == " ":
            temp += 1
    ans = max(ans, temp)
print(ans)
# Out:
# 6

# %%
li=[1,2,3]
for i in range(li[1]):
    print(i,"pop")
    for j in range (li[1]):
        print("loop",j)
# Out:
# 0 pop
# loop 0
# loop 1
# 1 pop
# loop 0
# loop 1

# %%
s="one problem a day"
ans=0
for i in range(len(s)):
    if s[i]==" ":
        ans+=1
print(ans)
# Out:
# 3

# %%
li="kv kvsmno dsvmon vdnon"
temp=0
for i in range(li(i)):
    if li == " ":
        temp=
# Out:
# 2

# %%
s="rajasekhar"
count=1
for i in range(len(s)):
    count+=1
print(i)
# Out:
# 9

# %%
s="raja sekhar rishi"
temp=0
for i in range(len(s)):
    if s[i]=="r":
        temp+=1
print(temp)
# Out:
# 3
