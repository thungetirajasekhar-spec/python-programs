# %%
li=[3,2]
for i in li:
    print("macha")
# Out:
# macha
# macha

# %%
li=[1,2,3,4,1,3,1,3,4]
count=0
for i in range(len(li)):
    if li[i]==4:
        count+=1
print(count)
# Out:
# 2

# %%
li=[12,3,4,2,18,5]    
tep=0
for i in li:
    if i%3==0 or i%2 ==0:
        tep=tep+1
print(tep)
# Out:
# 5

# %%
raj=[1,2,3,4]
for i in raj[::-1]:
    print(i,end="")
# Out:
# 4321

# %%
li="raj"
n=len(li)
for i in range(n-1,-1,-1):
    print(li[i],end=" ")
# Out:
# j a r
